# %% [markdown]
# # Chatbot

# %%
# !pip install transformers torch
# Out:
# ...
#   Using cached transformers-5.4.0-py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached huggingface_hub-1.8.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# ...
#   Using cached typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# ...
#   Using cached hf_xet-1.4.2-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# ...
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached transformers-5.4.0-py3-none-any.whl (10.1 MB)
# Using cached huggingface_hub-1.8.0-py3-none-any.whl (625 kB)
# Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# 1. Load the Pre-trained Model and Tokenizer
# We are using BlenderBot, a highly effective conversational transformer model from Hugging Face.
model_name = "facebook/blenderbot-400M-distill"
print("Loading the AI model... (This might take a minute on the first run)")

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# 2. Start the Interactive Conversation Loop
print("\n" + "="*50)
print("Chatbot starts and waits for input") #
print("Chatbot: Hello! I am your AI assistant. How can I help you today?") #

while True:
    # Get user input
    user_input = input("User: ")
    
    # 3. Exit Condition
    # Stop the chatbot when the user types 'exit' or 'quit'
    if user_input.lower() in ['exit', 'quit']:
        print("Chatbot ends the conversation") #
        break
        
    # 4. Model Processing
    # Tokenize the user's input so the transformer can understand it
    inputs = tokenizer(user_input, return_tensors="pt")
    
    # 5. Response Generation
    # Generate the reply IDs using the model
    reply_ids = model.generate(**inputs)
    
    # 6. Display Output
    # Decode the numerical IDs back into human-readable text
    response = tokenizer.decode(reply_ids[0], skip_special_tokens=True)
    
    print(f"Chatbot: {response}")

print("="*50)
# Out:
# Loading the AI model... (This might take a minute on the first run)
# ...
# Loading weights:   0%|          | 0/355 [00:00<?, ?it/s]
# ...
# Chatbot starts and waits for input
# Chatbot: Hello! I am your AI assistant. How can I help you today?
# User:  Hello, how are you?
# Chatbot:  I'm doing well, thank you. How are you this fine evening? Do you have any plans?
# User:  I am just studying Artificial Intelligence right now!" * "I don't have any plans. Can you tell me a joke?
# Chatbot:  I can't tell you a joke, but I do know that artificial intelligence is used in many fields of science and technology.
# User:  That is fascinating! What specific fields of science use AI the most?
# Chatbot:  I'm not sure, but I do know that it will be used in the field of robotics.
# User:  Robotics is definitely a huge field! Do you know of any famous robots?
# Chatbot:  I don't know any famous ones, but I do know that robotics has been around since the late 19th century.
# User:  exit
# ...
